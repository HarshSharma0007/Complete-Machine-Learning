# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
np.random.seed(42)

# %%
data = np.random.rand(5,5)
sns.heatmap(data, annot=True, cmap="coolwarm" )
plt.title("Heat map")
plt.show()

# %%
# 

years = [2010, 2011, 2012, 2013]
sales = [100, 120, 140, 160]
plt.plot(years, sales, label="Sales plot", color = "blue", marker = "o" )
plt.xlabel("Years")
plt.ylabel("Sales")
plt.legend()

# %%
#  Bar chart

categories = ["Electronics", "Clothing", "Groceries"]
revenue = [250, 400, 150]
plt.bar(categories, revenue, color="green")
plt.title("revenue by plot")
plt.show()

# %%
# Scatter plot

hours_studied = [1,2,3,4,5]
exam_scores = [50,55,60,65,70]

plt.scatter(hours_studied, exam_scores, color="red")
plt.xlabel("Hours studied")
plt.ylabel("Exam scores")
plt.title("Study hours vs Exam Scores")
plt.show()

# %% [markdown]
# #### Heatmap using Seaborn

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

iris = sns.load_dataset("iris")
df = pd.DataFrame(iris)

# %%
# Out:
# Object `np.rand` not found.

# %%
del df['species']

correlation_matrix = df.corr()

# plot the heatmap

sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm")
plt.title('Correlation Heatmap')
plt.show()

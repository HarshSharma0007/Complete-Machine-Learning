# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x = [1,2,3,4]
y=[10,20,25,30]

# %%
plt.plot(x,y)
plt.show()

# %% [markdown]
# ### LINE PLOT

# %%
plt.plot([1,2,3],[10,20,30],label="Trend",marker="o",linestyle="--", color="orange")
plt.title("Line Plot")
plt.xlabel("X-axis")
plt.ylabel("Y-axix")
plt.show()

# %% [markdown]
# ### BAR PLOT

# %%
categories = ["A","B","C"]
values = [10,15,7]
plt.bar(categories, values, color="blue")
plt.title("Bar Chart")
plt.show(
    
)

# %% [markdown]
# #### Histogram

# %%
data = [1,2,2,3,3,3,4,4,4,4]
plt.hist(data,bins=4,color="green",edgecolor="black")
plt.title("Histogram")
plt.show()

# %% [markdown]
# #### Scatter PLot

# %%
plt.scatter(x,y,color="red")
plt.title("Scatter Plot")
plt.show()

# %%
# Out:
# C:\Users\DELL\AppData\Roaming\Python\Python312\site-packages\scipy\_lib\doccer.py:72: RuntimeWarning: coroutine 'main' was never awaited
#   def inherit_docstring_from(cls):
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback

# %%
df = pd.read_csv("")
